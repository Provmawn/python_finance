# %%
import pandas_datareader.data as web

# %%
aapl_df = web.DataReader('AAPL', 'yahoo', start='2020-01-01', end='2021-01-01')

# %%
aapl_df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   99116600.0
#
#              Adj Close
# Date
# 2020-01-02   74.096466
# 2020-01-03   73.376091
# ...

# %%
inflation_df = web.DataReader('T10YIE', 'fred', start='2004-01-01', end='2021-01-01')

# %%
inflation_df.plot(ylabel='Inflation')
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='Inflation'>

# %%
import yfinance as yf

# %%
apple = yf.download('AAPL', start='2020-01-01', end='2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   74.096466
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   73.376076
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   73.960770
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   73.612930
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   74.797089
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.352844
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.050781
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.239273
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.094666
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  132.069473
#
#                Volume
# Date
# 2020-01-02  135480400
# 2020-01-03  146322800
# 2020-01-06  118387200
# ...

# %%
apple_ticker = yf.Ticker('AAPL')

# %%
apple_ticker.get_balance_sheet()
# Out:
#                              2021-09-25    2020-09-26    2019-09-28  \
# Total Liab                 2.879120e+11  2.585490e+11  2.480280e+11
# Total Stockholder Equity   6.309000e+10  6.533900e+10  9.048800e+10
# Other Current Liab         5.510500e+10  4.786700e+10  4.324200e+10
# Total Assets               3.510020e+11  3.238880e+11  3.385160e+11
# Common Stock               5.736500e+10  5.077900e+10  4.517400e+10
# Other Current Assets       1.411100e+10  1.126400e+10  1.235200e+10
# Retained Earnings          5.562000e+09  1.496600e+10  4.589800e+10
# Other Liab                 5.332500e+10  4.610800e+10  5.050300e+10
# Treasury Stock             1.630000e+08 -4.060000e+08 -5.840000e+08
# Other Assets               4.884900e+10  3.395200e+10  3.297800e+10
# Cash                       3.494000e+10  3.801600e+10  4.884400e+10
# Total Current Liabilities  1.254810e+11  1.053920e+11  1.057180e+11
# Short Long Term Debt       9.613000e+09  8.773000e+09  1.026000e+10
# ...

# %%
apple_ticker.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-05-11   0.000536           0.0
# 1987-06-16   0.000000           2.0
# 1987-08-10   0.000536           0.0
# 1987-11-17   0.000714           0.0
# 1988-02-12   0.000714           0.0
# ...               ...           ...
# 2020-08-31   0.000000           4.0
# 2020-11-06   0.205000           0.0
# 2021-02-05   0.205000           0.0
# 2021-05-07   0.220000           0.0
# 2021-08-06   0.220000           0.0
#
# [77 rows x 2 columns]
