# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/home_data.csv')

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df = df.set_index('id')

# %%
df
# Out:
#                        date   price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900         3       1.00         1180
# 6414100192  20141209T000000  538000         3       2.25         2570
# 5631500400  20150225T000000  180000         2       1.00          770
# 2487200875  20141209T000000  604000         4       3.00         1960
# 1954400510  20150218T000000  510000         3       2.00         1680
# ...                     ...     ...       ...        ...          ...
# 263000018   20140521T000000  360000         3       2.50         1530
# 6600060120  20150223T000000  400000         4       2.50         2310
# 1523300141  20140623T000000  402101         2       0.75         1020
# 291310100   20150116T000000  400000         3       2.50         1600
# 1523300157  20141015T000000  325000         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
df['date'].value_counts()
# Out:
# 20140623T000000    142
# 20140626T000000    131
# 20140625T000000    131
# 20140708T000000    127
# 20150427T000000    126
#                   ...
# 20141102T000000      1
# 20150131T000000      1
# 20150524T000000      1
# 20140517T000000      1
# 20140727T000000      1
# Name: date, Length: 372, dtype: int64

# %%
df['date'].unique()
# Out:
# array(['20141013T000000', '20141209T000000', '20150225T000000',
#        '20150218T000000', '20140512T000000', '20140627T000000',
#        '20150115T000000', '20150415T000000', '20150312T000000',
#        '20150403T000000', '20140527T000000', '20140528T000000',
#        '20141007T000000', '20150124T000000', '20140731T000000',
#        '20140529T000000', '20141205T000000', '20150424T000000',
#        '20140514T000000', '20140826T000000', '20140703T000000',
#        '20140516T000000', '20141120T000000', '20141103T000000',
#        '20140626T000000', '20141201T000000', '20140624T000000',
#        '20150302T000000', '20141110T000000', '20141203T000000',
#        '20140613T000000', '20141230T000000', '20150213T000000',
#        '20140620T000000', '20140715T000000', '20140811T000000',
#        '20140707T000000', '20141028T000000', '20140729T000000',
#        '20140718T000000', '20150325T000000', '20140716T000000',
#        '20150428T000000', '20150311T000000', '20140916T000000',
# ...

# %%
df['date'].nunique()
# Out:
# 372

# %%
df['date'].duplicated()
# Out:
# id
# 7129300520    False
# 6414100192    False
# 5631500400    False
# 2487200875     True
# 1954400510    False
#               ...
# 263000018      True
# 6600060120     True
# 1523300141     True
# 291310100      True
# 1523300157     True
# Name: date, Length: 21613, dtype: bool

# %%
df['date'].drop_duplicates()
# Out:
# id
# 7129300520    20141013T000000
# 6414100192    20141209T000000
# 5631500400    20150225T000000
# 1954400510    20150218T000000
# 7237550310    20140512T000000
#                    ...
# 4047200825    20141011T000000
# 2064800880    20150201T000000
# 126059310     20141130T000000
# 984220330     20140824T000000
# 2827100075    20140727T000000
# Name: date, Length: 372, dtype: object

# %%
df[df['price'].between(100000, 200000)]
# Out:
#                        date   price  bedrooms  bathrooms  sqft_living  \
# id
# 5631500400  20150225T000000  180000         2       1.00          770
# 16000397    20141205T000000  189000         2       1.00         1200
# 4168000060  20150226T000000  153000         3       1.00         1200
# 1099611230  20140912T000000  199000         4       1.50         1160
# 3530510041  20140723T000000  188500         2       1.75         1240
# ...                     ...     ...       ...        ...          ...
# 6056100150  20140623T000000  160797         3       1.50         1270
# 2724049222  20140802T000000  163800         2       2.50         1000
# 6056100160  20140728T000000  182568         4       1.50         1500
# 1278000210  20150311T000000  110000         2       1.00          828
# 2781270530  20150326T000000  193000         2       1.75          910
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.nsmallest(2, 'price')
# Out:
#                        date  price  bedrooms  bathrooms  sqft_living  \
# id
# 3421079032  20150217T000000  75000         1        0.0          670
# 40000362    20140506T000000  78000         2        1.0          780
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 3421079032     43377     1.0           0     0          3      3         670
# 40000362       16344     1.0           0     0          1      5         780
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 3421079032              0      1966             0    98022  47.2638 -121.906
# 40000362                0      1942             0    98168  47.4739 -122.280
#
#             sqft_living15  sqft_lot15
# id
# 3421079032           1160       42882
# 40000362             1700       10387

# %%
df.nlargest(2, 'price')
# Out:
#                        date    price  bedrooms  bathrooms  sqft_living  \
# id
# 6762700020  20141013T000000  7700000         6        8.0        12050
# 9808700762  20140611T000000  7062500         5        4.5        10040
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 6762700020     27600     2.5           0     3          4     13        8570
# 9808700762     37325     2.0           1     2          3     11        7680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 6762700020           3480      1910          1987    98102  47.6298 -122.323
# 9808700762           2360      1940          2001    98004  47.6500 -122.214
#
#             sqft_living15  sqft_lot15
# id
# 6762700020           3940        8800
# 9808700762           3930       25449

# %%
df.sort_values('price').iloc[:2]
# Out:
#                        date  price  bedrooms  bathrooms  sqft_living  \
# id
# 3421079032  20150217T000000  75000         1        0.0          670
# 40000362    20140506T000000  78000         2        1.0          780
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 3421079032     43377     1.0           0     0          3      3         670
# 40000362       16344     1.0           0     0          1      5         780
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 3421079032              0      1966             0    98022  47.2638 -121.906
# 40000362                0      1942             0    98168  47.4739 -122.280
#
#             sqft_living15  sqft_lot15
# id
# 3421079032           1160       42882
# 40000362             1700       10387

# %%
df.sort_values('price', ascending=False).iloc[:2]
# Out:
#                        date    price  bedrooms  bathrooms  sqft_living  \
# id
# 6762700020  20141013T000000  7700000         6        8.0        12050
# 9808700762  20140611T000000  7062500         5        4.5        10040
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 6762700020     27600     2.5           0     3          4     13        8570
# 9808700762     37325     2.0           1     2          3     11        7680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 6762700020           3480      1910          1987    98102  47.6298 -122.323
# 9808700762           2360      1940          2001    98004  47.6500 -122.214
#
#             sqft_living15  sqft_lot15
# id
# 6762700020           3940        8800
# 9808700762           3930       25449

# %%
df.sample(5)
# Out:
#                        date    price  bedrooms  bathrooms  sqft_living  \
# id
# 5288200070  20140730T000000   450000         3        1.0         1450
# 3904910610  20150506T000000   700000         4        2.5         2490
# 3738000070  20150309T000000  1712750         5        2.5         2660
# 5006000035  20150427T000000   332500         4        1.0         1670
# 7135300046  20140716T000000   210000         2        1.0         1450
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 5288200070      3350     1.5           0     0          4      7        1450
# 3904910610      7694     2.0           0     0          3      8        2490
# 3738000070      6572     1.0           0     0          5      9        1960
# 5006000035      8102     1.5           0     0          3      6        1670
# 7135300046      4750     1.0           0     0          3      7         850
#
# ...

# %%
df.sample(frac=0.1)
# Out:
#                        date   price  bedrooms  bathrooms  sqft_living  \
# id
# 9169100214  20140514T000000  372220         3       1.00         1290
# 4318200405  20140620T000000  850000         3       2.25         2870
# 5450900010  20140821T000000  993500         4       2.25         4070
# 6163901380  20141114T000000  244000         2       1.00          960
# 4136890260  20140627T000000  327000         5       2.75         2400
# ...                     ...     ...       ...        ...          ...
# 2921700060  20141027T000000  535000         4       1.00         1920
# 1310000130  20140924T000000  315000         4       2.00         2020
# 7335400020  20140626T000000  219500         3       1.00         1090
# 3211240320  20140612T000000  489950         4       2.25         2640
# 133000070   20140916T000000  179900         2       1.00          680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
one = np.array(['A0','B0', 'A1', 'B1', 'A2', 'B2', 'A3', 'B3'])

# %%
one.reshape(4,2)
# Out:
# array([['A0', 'B0'],
#        ['A1', 'B1'],
#        ['A2', 'B2'],
#        ['A3', 'B3']], dtype='<U2')

# %%
one = one.reshape(4,2)
mycolumns = ['A', 'B']

# %%
one = pd.DataFrame(one, columns=mycolumns)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two = pd.DataFrame(np.array(['C0', 'D0', 'C1', 'D1', 'C2', 'D2', 'C3', 'D3']).reshape(4, 2), columns=['C', 'D'])

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
pd.concat([one, two], axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([one, two], axis=0)
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
 two.columns = one.columns

# %%
mydf = pd.concat([one, two], axis=0)

# %%
mydf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
 mydf.index = range(len(mydf))

# %%
mydf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  C0  D0
# 5  C1  D1
# 6  C2  D2
# 7  C3  D3

# %%
mydf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  C0  D0
# 5  C1  D1
# 6  C2  D2
# 7  C3  D3

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df = df.set_index('id')

# %%
df
# Out:
#                        date   price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900         3       1.00         1180
# 6414100192  20141209T000000  538000         3       2.25         2570
# 5631500400  20150225T000000  180000         2       1.00          770
# 2487200875  20141209T000000  604000         4       3.00         1960
# 1954400510  20150218T000000  510000         3       2.00         1680
# ...                     ...     ...       ...        ...          ...
# 263000018   20140521T000000  360000         3       2.50         1530
# 6600060120  20150223T000000  400000         4       2.50         2310
# 1523300141  20140623T000000  402101         2       0.75         1020
# 291310100   20150116T000000  400000         3       2.50         1600
# 1523300157  20141015T000000  325000         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.to_csv('housing_new.csv')

# %%
ls
# Out:
# Untitled.ipynb  datasets/  housing_new.csv  series.ipynb

# %%
ls datasets
# Out:
# FRB_H15.csv  home_data.csv

# %%
mv housing_new.csv datasets/

# %%
ls datasets/
# Out:
# FRB_H15.csv  home_data.csv  housing_new.csv
