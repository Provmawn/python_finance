# %%
import numpy as np

# %%
import pandas as pd

# %%
#help(pd.Series)

# %%
myindex = ['USA', 'Canada', 'Mexico']

# %%
mydata = [1776, 1867, 1821]

# %%
myser = pd.Series(data=mydata, index=myindex)

# %%
myser
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
myser[0]
# Out:
# 1776

# %%
myser['USA']
# Out:
# 1776

# %%
ages = {'Sam':5, 'Frank':10, 'Spike':7}

# %%
pd.Series(ages)
# Out:
# Sam       5
# Frank    10
# Spike     7
# dtype: int64

# %%
q1 = {'Japan':80, 'China':450, 'India':200, 'USA':250}
q2 = {'Brazil':100, 'China':500, 'India':210, 'USA':260}

# %%
sales_q1 = pd.Series(q1)

# %%
sales_q2 = pd.Series(q2)

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q2.keys()
# Out:
# Index(['Brazil', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1.add(sales_q2, fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
np.random.seed(101)

# %%
mydata = np.random.randint(0, 101, [4,3])

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA', 'NY', 'AZ', 'TX']

# %%
mycolumns = ['Jan', 'Feb', 'Mar']

# %%
df = pd.DataFrame(mydata, index=myindex, columns=mycolumns)

# %%
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
pwd
# Out:
# '/home/neuro/workspace/udemy/python/trading/pandas'

# %%
ls
# Out:
# datasets/  series.ipynb

# %%
df = pd.read_csv('datasets/home_data.csv')

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=21613, step=1)

# %%
df.head(10)
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900         3       1.00         1180
# 1  6414100192  20141209T000000   538000         3       2.25         2570
# 2  5631500400  20150225T000000   180000         2       1.00          770
# 3  2487200875  20141209T000000   604000         4       3.00         1960
# 4  1954400510  20150218T000000   510000         3       2.00         1680
# 5  7237550310  20140512T000000  1225000         4       4.50         5420
# 6  1321400060  20140627T000000   257500         3       2.25         1715
# 7  2008000270  20150115T000000   291850         3       1.50         1060
# 8  2414600126  20150415T000000   229500         3       1.00         1780
# 9  3793500160  20150312T000000   323000         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df['price']
# Out:
# 0        221900
# 1        538000
# 2        180000
# 3        604000
# 4        510000
#           ...
# 21608    360000
# 21609    400000
# 21610    402101
# 21611    400000
# 21612    325000
# Name: price, Length: 21613, dtype: int64

# %%
 df[['price', 'bedrooms']]
# Out:
#         price  bedrooms
# 0      221900         3
# 1      538000         3
# 2      180000         2
# 3      604000         4
# 4      510000         3
# ...       ...       ...
# 21608  360000         3
# 21609  400000         4
# 21610  402101         2
# 21611  400000         3
# 21612  325000         2
#
# [21613 rows x 2 columns]

# %%
df['bedroom_percent'] = np.round(100 * df['price'] / df['bedrooms'], 2)

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df = df.drop(['lat','long'], axis=1)

# %%
df.set_index('id')
# Out:
#                        date   price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900         3       1.00         1180
# 6414100192  20141209T000000  538000         3       2.25         2570
# 5631500400  20150225T000000  180000         2       1.00          770
# 2487200875  20141209T000000  604000         4       3.00         1960
# 1954400510  20150218T000000  510000         3       2.00         1680
# ...                     ...     ...       ...        ...          ...
# 263000018   20140521T000000  360000         3       2.50         1530
# 6600060120  20150223T000000  400000         4       2.50         2310
# 1523300141  20140623T000000  402101         2       0.75         1020
# 291310100   20150116T000000  400000         3       2.50         1600
# 1523300157  20141015T000000  325000         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df = df.drop('id', axis=1)

# %%
df
# Out:
#                   date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900         3       1.00         1180      5650
# 1      20141209T000000  538000         3       2.25         2570      7242
# 2      20150225T000000  180000         2       1.00          770     10000
# 3      20141209T000000  604000         4       3.00         1960      5000
# 4      20150218T000000  510000         3       2.00         1680      8080
# ...                ...     ...       ...        ...          ...       ...
# 21608  20140521T000000  360000         3       2.50         1530      1131
# 21609  20150223T000000  400000         4       2.50         2310      5813
# 21610  20140623T000000  402101         2       0.75         1020      1350
# 21611  20150116T000000  400000         3       2.50         1600      2388
# 21612  20141015T000000  325000         2       0.75         1020      1076
#
# ...

# %%
df.set_index('date')
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000  221900         3       1.00         1180      5650     1.0
# 20141209T000000  538000         3       2.25         2570      7242     2.0
# 20150225T000000  180000         2       1.00          770     10000     1.0
# 20141209T000000  604000         4       3.00         1960      5000     1.0
# 20150218T000000  510000         3       2.00         1680      8080     1.0
# ...                 ...       ...        ...          ...       ...     ...
# 20140521T000000  360000         3       2.50         1530      1131     3.0
# 20150223T000000  400000         4       2.50         2310      5813     2.0
# 20140623T000000  402101         2       0.75         1020      1350     2.0
# 20150116T000000  400000         3       2.50         1600      2388     2.0
# 20141015T000000  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
df.reset_index()
# Out:
#        index             date   price  bedrooms  bathrooms  sqft_living  \
# 0          0  20141013T000000  221900         3       1.00         1180
# 1          1  20141209T000000  538000         3       2.25         2570
# 2          2  20150225T000000  180000         2       1.00          770
# 3          3  20141209T000000  604000         4       3.00         1960
# 4          4  20150218T000000  510000         3       2.00         1680
# ...      ...              ...     ...       ...        ...          ...
# 21608  21608  20140521T000000  360000         3       2.50         1530
# 21609  21609  20150223T000000  400000         4       2.50         2310
# 21610  21610  20140623T000000  402101         2       0.75         1020
# 21611  21611  20150116T000000  400000         3       2.50         1600
# 21612  21612  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
df.set_index('date')
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000  221900         3       1.00         1180      5650     1.0
# 20141209T000000  538000         3       2.25         2570      7242     2.0
# 20150225T000000  180000         2       1.00          770     10000     1.0
# 20141209T000000  604000         4       3.00         1960      5000     1.0
# 20150218T000000  510000         3       2.00         1680      8080     1.0
# ...                 ...       ...        ...          ...       ...     ...
# 20140521T000000  360000         3       2.50         1530      1131     3.0
# 20150223T000000  400000         4       2.50         2310      5813     2.0
# 20140623T000000  402101         2       0.75         1020      1350     2.0
# 20150116T000000  400000         3       2.50         1600      2388     2.0
# 20141015T000000  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
df = df.drop('bedroom_percent', axis=1)

# %%
df
# Out:
#                   date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900         3       1.00         1180      5650
# 1      20141209T000000  538000         3       2.25         2570      7242
# 2      20150225T000000  180000         2       1.00          770     10000
# 3      20141209T000000  604000         4       3.00         1960      5000
# 4      20150218T000000  510000         3       2.00         1680      8080
# ...                ...     ...       ...        ...          ...       ...
# 21608  20140521T000000  360000         3       2.50         1530      1131
# 21609  20150223T000000  400000         4       2.50         2310      5813
# 21610  20140623T000000  402101         2       0.75         1020      1350
# 21611  20150116T000000  400000         3       2.50         1600      2388
# 21612  20141015T000000  325000         2       0.75         1020      1076
#
# ...

# %%
df = df.set_index('date')

# %%
df
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000  221900         3       1.00         1180      5650     1.0
# 20141209T000000  538000         3       2.25         2570      7242     2.0
# 20150225T000000  180000         2       1.00          770     10000     1.0
# 20141209T000000  604000         4       3.00         1960      5000     1.0
# 20150218T000000  510000         3       2.00         1680      8080     1.0
# ...                 ...       ...        ...          ...       ...     ...
# 20140521T000000  360000         3       2.50         1530      1131     3.0
# 20150223T000000  400000         4       2.50         2310      5813     2.0
# 20140623T000000  402101         2       0.75         1020      1350     2.0
# 20150116T000000  400000         3       2.50         1600      2388     2.0
# 20141015T000000  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
df.loc['20141013T000000']
# Out:
#                    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000   221900         3       1.00         1180      5650     1.0
# 20141013T000000   380000         4       1.75         1760      7300     1.0
# 20141013T000000   318888         4       1.75         2320     12000     1.0
# 20141013T000000  1450000         3       3.00         4380      6320     2.0
# 20141013T000000   400000         4       1.00         1420      4875     1.5
# ...                  ...       ...        ...          ...       ...     ...
# 20141013T000000  1210000         4       3.25         3330      9000     2.0
# 20141013T000000   577450         3       3.00         1730      1755     3.0
# 20141013T000000   300000         3       2.50         1960      1477     2.0
# 20141013T000000   349950         4       2.50         2632      4117     2.0
# 20141013T000000   541800         4       2.50         3118      7866     2.0
#
# ...

# %%
df.iloc[0]
# Out:
# price            221900.0
# bedrooms              3.0
# bathrooms             1.0
# sqft_living        1180.0
# sqft_lot           5650.0
# floors                1.0
# waterfront            0.0
# view                  0.0
# condition             3.0
# grade                 7.0
# sqft_above         1180.0
# sqft_basement         0.0
# yr_built           1955.0
# yr_renovated          0.0
# zipcode           98178.0
# sqft_living15      1340.0
# sqft_lot15         5650.0
# Name: 20141013T000000, dtype: float64

# %%
one_row = df.iloc[0]

# %%
df.append(one_row)
# Out:
#                     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000  221900.0       3.0       1.00       1180.0    5650.0     1.0
# 20141209T000000  538000.0       3.0       2.25       2570.0    7242.0     2.0
# 20150225T000000  180000.0       2.0       1.00        770.0   10000.0     1.0
# 20141209T000000  604000.0       4.0       3.00       1960.0    5000.0     1.0
# 20150218T000000  510000.0       3.0       2.00       1680.0    8080.0     1.0
# ...                   ...       ...        ...          ...       ...     ...
# 20150223T000000  400000.0       4.0       2.50       2310.0    5813.0     2.0
# 20140623T000000  402101.0       2.0       0.75       1020.0    1350.0     2.0
# 20150116T000000  400000.0       3.0       2.50       1600.0    2388.0     2.0
# 20141015T000000  325000.0       2.0       0.75       1020.0    1076.0     2.0
# 20141013T000000  221900.0       3.0       1.00       1180.0    5650.0     1.0
#
# ...

# %%
df[(df['price'] < 1000000) & (df['price'] > 200000)]
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000  221900         3       1.00         1180      5650     1.0
# 20141209T000000  538000         3       2.25         2570      7242     2.0
# 20141209T000000  604000         4       3.00         1960      5000     1.0
# 20150218T000000  510000         3       2.00         1680      8080     1.0
# 20140627T000000  257500         3       2.25         1715      6819     2.0
# ...                 ...       ...        ...          ...       ...     ...
# 20140521T000000  360000         3       2.50         1530      1131     3.0
# 20150223T000000  400000         4       2.50         2310      5813     2.0
# 20140623T000000  402101         2       0.75         1020      1350     2.0
# 20150116T000000  400000         3       2.50         1600      2388     2.0
# 20141015T000000  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
df[df['floors'].isin([2, 3])]
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141209T000000  538000         3       2.25         2570      7242     2.0
# 20140627T000000  257500         3       2.25         1715      6819     2.0
# 20150312T000000  323000         3       2.50         1890      6560     2.0
# 20150124T000000  650000         4       3.00         2950      5000     2.0
# 20140731T000000  395000         3       2.00         1890     14040     2.0
# ...                 ...       ...        ...          ...       ...     ...
# 20140521T000000  360000         3       2.50         1530      1131     3.0
# 20150223T000000  400000         4       2.50         2310      5813     2.0
# 20140623T000000  402101         2       0.75         1020      1350     2.0
# 20150116T000000  400000         3       2.50         1600      2388     2.0
# 20141015T000000  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
def divide_by_100(num):
    return num / 100

# %%
df['price_per_hundred'] = df['price'].apply(divide_by_100)

# %%
df
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000  221900         3       1.00         1180      5650     1.0
# 20141209T000000  538000         3       2.25         2570      7242     2.0
# 20150225T000000  180000         2       1.00          770     10000     1.0
# 20141209T000000  604000         4       3.00         1960      5000     1.0
# 20150218T000000  510000         3       2.00         1680      8080     1.0
# ...                 ...       ...        ...          ...       ...     ...
# 20140521T000000  360000         3       2.50         1530      1131     3.0
# 20150223T000000  400000         4       2.50         2310      5813     2.0
# 20140623T000000  402101         2       0.75         1020      1350     2.0
# 20150116T000000  400000         3       2.50         1600      2388     2.0
# 20141015T000000  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
df['price'].apply(lambda num: num * 2)
# Out:
# date
# 20141013T000000     443800
# 20141209T000000    1076000
# 20150225T000000     360000
# 20141209T000000    1208000
# 20150218T000000    1020000
#                     ...
# 20140521T000000     720000
# 20150223T000000     800000
# 20140623T000000     804202
# 20150116T000000     800000
# 20141015T000000     650000
# Name: price, Length: 21613, dtype: int64

# %%
def price_floors(price, floors):
    return price / floors

# %%
df['price_per_floors'] = df[['price', 'floors']].apply(lambda df: price_floors(df['price'], df['floors']), axis=1)

# %%
df
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20141013T000000  221900         3       1.00         1180      5650     1.0
# 20141209T000000  538000         3       2.25         2570      7242     2.0
# 20150225T000000  180000         2       1.00          770     10000     1.0
# 20141209T000000  604000         4       3.00         1960      5000     1.0
# 20150218T000000  510000         3       2.00         1680      8080     1.0
# ...                 ...       ...        ...          ...       ...     ...
# 20140521T000000  360000         3       2.50         1530      1131     3.0
# 20150223T000000  400000         4       2.50         2310      5813     2.0
# 20140623T000000  402101         2       0.75         1020      1350     2.0
# 20150116T000000  400000         3       2.50         1600      2388     2.0
# 20141015T000000  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
df.sort_values('price')
# Out:
#                    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 20150217T000000    75000         1       0.00          670     43377     1.0
# 20140506T000000    78000         2       1.00          780     16344     1.0
# 20140523T000000    80000         1       0.75          430      5050     1.0
# 20150324T000000    81000         2       1.00          730      9975     1.0
# 20141105T000000    82000         3       1.00          860     10426     1.0
# ...                  ...       ...        ...          ...       ...     ...
# 20150413T000000  5350000         5       5.00         8000     23985     2.0
# 20140804T000000  5570000         5       5.75         9200     35069     2.0
# 20140919T000000  6885000         6       7.75         9890     31374     2.0
# 20140611T000000  7062500         5       4.50        10040     37325     2.0
# 20141013T000000  7700000         6       8.00        12050     27600     2.5
#
# ...

# %%
df['price'].min()
# Out:
# 75000

# %%
df = df.reset_index()

# %%
df.iloc[df['price'].idxmin()]
# Out:
# date                 20150217T000000
# price                          75000
# bedrooms                           1
# bathrooms                        0.0
# sqft_living                      670
# sqft_lot                       43377
# floors                           1.0
# waterfront                         0
# view                               0
# condition                          3
# grade                              3
# sqft_above                       670
# sqft_basement                      0
# yr_built                        1966
# yr_renovated                       0
# zipcode                        98022
# sqft_living15                   1160
# sqft_lot15                     42882
# price_per_hundred              750.0
# price_per_floors             75000.0
# Name: 1149, dtype: object

# %%
df.corr()
# Out:
#                       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# price              1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms           0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms          0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living        0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot           0.089661  0.031703   0.087740     0.172826  1.000000
# floors             0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront         0.266369 -0.006582   0.063744     0.103818  0.021604
# view               0.397293  0.079532   0.187737     0.284611  0.074710
# condition          0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade              0.667434  0.356967   0.664983     0.762704  0.113621
# sqft_above         0.605567  0.477600   0.685342     0.876597  0.183512
# sqft_basement      0.323816  0.303093   0.283770     0.435043  0.015286
# ...

# %%
df
# Out:
#                   date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900         3       1.00         1180      5650
# 1      20141209T000000  538000         3       2.25         2570      7242
# 2      20150225T000000  180000         2       1.00          770     10000
# 3      20141209T000000  604000         4       3.00         1960      5000
# 4      20150218T000000  510000         3       2.00         1680      8080
# ...                ...     ...       ...        ...          ...       ...
# 21608  20140521T000000  360000         3       2.50         1530      1131
# 21609  20150223T000000  400000         4       2.50         2310      5813
# 21610  20140623T000000  402101         2       0.75         1020      1350
# 21611  20150116T000000  400000         3       2.50         1600      2388
# 21612  20141015T000000  325000         2       0.75         1020      1076
#
# ...

# %%
df = df.drop(['price_per_hundred', 'price_per_floors'], axis=1)
