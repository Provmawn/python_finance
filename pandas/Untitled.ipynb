# %%
import pandas as pd

# %%
constituents = pd.read_csv('datasets/constituents_csv.csv')

# %%
financials = pd.read_csv('datasets/constituents-financials_csv.csv')

# %%
constituents.columns
# Out:
# Index(['Symbol', 'Name', 'Sector'], dtype='object')

# %%
financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          505 non-null    object
#  1   Name            505 non-null    object
#  2   Sector          505 non-null    object
#  3   Price           505 non-null    float64
#  4   Price/Earnings  503 non-null    float64
#  5   Dividend Yield  505 non-null    float64
#  6   Earnings/Share  505 non-null    float64
#  7   52 Week Low     505 non-null    float64
#  8   52 Week High    505 non-null    float64
#  9   Market Cap      505 non-null    int64
#  10  EBITDA          505 non-null    float64
#  11  Price/Sales     505 non-null    float64
#  12  Price/Book      497 non-null    float64
#  13  SEC Filings     505 non-null    object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 55.4+ KB

# %%
financials.head(5)
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  138721055226
# 1        1.147959            1.70        68.39        48.925   10783419933
# 2        1.908982            0.26        64.60        42.280  102121042306
# 3        2.499560            3.29       125.86        60.050  181386347059
# 4        1.714470            5.44       162.60       114.820   98765855553
#
#          EBITDA  Price/Sales  Price/Book  \
# ...

# %%
financials = financials.drop('SEC Filings', axis=1)

# %%
financials
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
financials = financials.set_index('Symbol')

# %%
financials['Market Cap'].nlargest(10)
# Out:
# Symbol
# AAPL     809508034020
# GOOGL    733823966137
# GOOG     728535558140
# MSFT     689978437468
# AMZN     685873374731
# FB       523423036576
# JPM      386613611000
# JNJ      353062464971
# XOM      326148660000
# BAC      321478200969
# Name: Market Cap, dtype: int64

# %%
financials.sort_values('Market Cap', ascending=False).head(10)
# Out:
#                         Name                  Sector    Price  Price/Earnings  \
# Symbol
# AAPL              Apple Inc.  Information Technology   155.15           16.86
# GOOGL   Alphabet Inc Class A  Information Technology  1007.71           31.48
# GOOG    Alphabet Inc Class C  Information Technology  1001.52           40.29
# MSFT         Microsoft Corp.  Information Technology    85.01           25.76
# AMZN          Amazon.com Inc  Consumer Discretionary  1350.50          296.16
# FB            Facebook, Inc.  Information Technology   171.58           27.90
# JPM     JPMorgan Chase & Co.              Financials   107.88           15.43
# JNJ        Johnson & Johnson             Health Care   126.36           17.31
# XOM        Exxon Mobil Corp.                  Energy    76.07           21.37
# BAC     Bank of America Corp              Financials    29.74           16.34
#
#         Dividend Yield  Earnings/Share  52 Week Low  52 Week High  \
# Symbol
# ...

# %%
financials = financials.drop('GOOG', axis=0)

# %%
financials.nlargest(10, 'Market Cap')
# Out:
#                         Name                  Sector    Price  Price/Earnings  \
# Symbol
# AAPL              Apple Inc.  Information Technology   155.15           16.86
# GOOGL   Alphabet Inc Class A  Information Technology  1007.71           31.48
# MSFT         Microsoft Corp.  Information Technology    85.01           25.76
# AMZN          Amazon.com Inc  Consumer Discretionary  1350.50          296.16
# FB            Facebook, Inc.  Information Technology   171.58           27.90
# JPM     JPMorgan Chase & Co.              Financials   107.88           15.43
# JNJ        Johnson & Johnson             Health Care   126.36           17.31
# XOM        Exxon Mobil Corp.                  Energy    76.07           21.37
# BAC     Bank of America Corp              Financials    29.74           16.34
# WMT          Wal-Mart Stores        Consumer Staples   100.02           23.10
#
#         Dividend Yield  Earnings/Share  52 Week Low  52 Week High  \
# Symbol
# ...

# %%
financials[financials['Dividend Yield'] > 4]
# Out:
#                                   Name                      Sector   Price  \
# Symbol
# AES                           AES Corp                   Utilities   10.06
# T                             AT&T Inc  Telecommunication Services   35.57
# CNP                 CenterPoint Energy                   Utilities   25.85
# CTL                    CenturyLink Inc  Telecommunication Services   16.20
# D                      Dominion Energy                   Utilities   73.31
# DUK                        Duke Energy                   Utilities   74.32
# EIX                       Edison Int'l                   Utilities   58.07
# ETR                      Entergy Corp.                   Utilities   72.02
# XOM                  Exxon Mobil Corp.                      Energy   76.07
# FE                    FirstEnergy Corp                   Utilities   30.64
# F                           Ford Motor      Consumer Discretionary   10.43
# ...

# %%
financials[financials['Market Cap'] > 1e11]['Earnings/Share'].mean()
# Out:
# 4.746470588235293

# %%
len(financials[financials['Earnings/Share']>0])
# Out:
# 452

# %%
financials.loc[financials['Dividend Yield'].idxmax()]['52 Week High']
# Out:
# 13.161

# %%
abs(financials['52 Week High'] - financials['52 Week Low']).idxmax()
# Out:
# 'AMZN'

# %%
financials[financials['Price'].between(50, 100)]
# Out:
#                             Name                  Sector  Price  \
# Symbol
# AOS              A.O. Smith Corp             Industrials  60.24
# ABT          Abbott Laboratories             Health Care  56.27
# ATVI         Activision Blizzard  Information Technology  65.83
# AFL                    AFLAC Inc              Financials  83.25
# A       Agilent Technologies Inc             Health Care  65.05
# ...                          ...                     ...    ...
# XLNX                  Xilinx Inc  Information Technology  62.82
# XYL                   Xylem Inc.             Industrials  70.24
# YUM              Yum! Brands Inc  Consumer Discretionary  76.30
# ZION               Zions Bancorp              Financials  50.71
# ZTS                       Zoetis             Health Care  71.51
#
#         Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# AOS              27.76        1.147959            1.70       68.390
# ...

# %%
financials['Market Cap in B'] = financials['Market Cap'] / 1000000000

# %%
financials
# Out:
#                           Name                  Sector   Price  \
# Symbol
# MMM                 3M Company             Industrials  222.89
# AOS            A.O. Smith Corp             Industrials   60.24
# ABT        Abbott Laboratories             Health Care   56.27
# ABBV               AbbVie Inc.             Health Care  108.48
# ACN              Accenture plc  Information Technology  150.51
# ...                        ...                     ...     ...
# XYL                 Xylem Inc.             Industrials   70.24
# YUM            Yum! Brands Inc  Consumer Discretionary   76.30
# ZBH     Zimmer Biomet Holdings             Health Care  115.53
# ZION             Zions Bancorp              Financials   50.71
# ZTS                     Zoetis             Health Care   71.51
#
#         Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM              24.31        2.332862            7.92       259.77
# ...

# %%
financials[['Market Cap', 'Dividend Yield']].corr()
# Out:
#                 Market Cap  Dividend Yield
# Market Cap        1.000000       -0.003506
# Dividend Yield   -0.003506        1.000000

# %%
merged_df = pd.merge(financials, constituents, on='Symbol', suffixes=['_fin','_con'])

# %%
merged_df
# Out:
#     Symbol                Name_fin              Sector_fin   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 499    XYL              Xylem Inc.             Industrials   70.24
# 500    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 501    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 502   ZION           Zions Bancorp              Financials   50.71
# 503    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...
